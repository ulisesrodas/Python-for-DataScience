# %% [markdown]
# # PANDAS Y DATAFRAMES

# %%
# !pip -q install pyreadstat # Lee archivos Stata, SPSS y SAS

# %% [markdown]
# - <a href='#1.'>I. `Pandas`</a>
#      - <a href='#1.1.'>1.1. Definición y Características</a>
#      - <a href='#1.2.'>1.2. Generación de `Series`</a>
#      - <a href='#1.3.'>1.3. `Series` vs `NumPy`</a>
#      - <a href='#1.4.'>1.4. Indexar</a></a>
# - <a href='#2.'>II. `DataFrames`</a>
#      - <a href='#2.1.'>2.1. Generación de `DataFrames`</a>
#      - <a href='#2.2.'>2.2. Indexing</a>
#      - <a href='#2.3.'>2.3. Métodos Generales</a>
#      - <a href='#2.4.'>2.4. Importando Data: GitHub</a>
#      - <a href='#2.5.'>2.5. Importando Data: ENAPRES</a>

# %% [markdown]
# # <a id='1.'>I. `Pandas`</a>

# %% [markdown]
# ## <a id='1.1.'>1.1. Definición y Características</a>

# %% [markdown]
# **DEFINICIÓN:**
#
# * `Pandas` es una biblioteca de Python utilizada para trabajar con conjuntos de datos: vamos a llamarla cada vez que trabajamos con DataFrames.
# * Es la librería más importante de aprender para limpiar, transforar y agregar datos.
# * Como es externa, necesitamos importarla para trabajar en nuestro quehacer diario mediante la palabra clave `import`.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# * Ahora, el paquete de `Pandas` está referido como `pd` en lugar de Pandas.

# %% [markdown]
# **CARACTERÍSTICAS:**
#
# * La primera estructura de datos de `Pandas` es una Serie, que es un arreglo unidimensional que puede contener cualquier tipo de datos, de manera similar a un ndarray.
# * Tiene un índice (index) que le asigna una etiqueta a cada entrada. Por lo general, el índice se utiliza para etiquetar los datos.
# * Contiene información sobre una sola característica (feature) de los datos.
# * Un `Pandas Dataframe` son muchas Series.

# %% [markdown]
# ## <a id='1.2.'>1.2. Generación de `Series`<a>

# %% [markdown]
# ### De `lists` a `Series`:

# %%
# Recordemos una lista de Python, vista la clase pasada:
list1 = [0.25, 0.5, 0.75, 1.0]
list1
# Out:
# [0.25, 0.5, 0.75, 1.0]

# %%
# Se puede decir que una Serie es una columna:
pd.Series([1, 5, 8, 9, 10])
# Out:
# 0     1
# 1     5
# 2     8
# 3     9
# 4    10
# dtype: int64

# %%
list2 =  [1, 1.5, 2, 2.5, 3]
list2
# Out:
# [1, 1.5, 2, 2.5, 3]

# %%
# Convertimos la lista en una Serie de Pandas:
data = pd.Series(list2)
data
# Out:
# 0    1.0
# 1    1.5
# 2    2.0
# 3    2.5
# 4    3.0
# dtype: float64

# %%
# Ya tenemos nuestros datos convertidos a Series
print(data)
# Out:
# 0    1.0
# 1    1.5
# 2    2.0
# 3    2.5
# 4    3.0
# dtype: float64

# %% [markdown]
# * **Una base de datos es un conjunto de Series.**
# * Podemos convertir un Numpy y diccionarios a Series también.

# %% [markdown]
# ### De `NumPy array` a `Series`:

# %%
# Veamos un ejemplo de un vector de Numpy, que es otra estructura de datos muy utilizada en Python
# La clase pasada vimos que un vector es una lista de números:
vector1 = np.array([10, 20, 1, 2, 
                    3, 4, 5, 6, 7, 10])
vector1
# Out:
# array([10, 20,  1,  2,  3,  4,  5,  6,  7, 10])

# %%
# Ahora convertimos el vector de Numpy a una Serie de Pandas:
series1 = pd.Series( vector1 )
series1
# Out:
# 0    10
# 1    20
# 2     1
# 3     2
# 4     3
# 5     4
# 6     5
# 7     6
# 8     7
# 9    10
# dtype: int32

# %%
# Las Series de Pandas son más complejas que los vectores de Numpy, ya que permiten almacenar información adicional como el índice y el nombre de la Serie.
print(type(vector1))
print(type(series1))
# Out:
# <class 'numpy.ndarray'>
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ### De `Dictionary` a `Series`:

# %%
population_dict= { 'California' : 38332521,
                    'Texas'      : 26448193,
                    'New York'   : 19651127,
                    'Florida'    : 19552860,
                    'Illinois'   : 12882135 }

# %%
# Vemos las llaves:
population_dict.keys()
# Out:
# dict_keys(['California', 'Texas', 'New York', 'Florida', 'Illinois'])

# %%
# Al convertirlo en Series, la indexación absorde las llaves.
# Por tanto, la indexación también puede tener texto. Sin embargo, no es lo ideal. Se recomienda números partiendo desde 0.
population = pd.Series( population_dict )
population
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64

# %% [markdown]
# ## <a id='1.3.'>1.3. `Series` vs `NumPy`</a>
#
# * La diferencia esencial es la presencia del índice: mientras que el `Numpy Array` tiene un índice entero definido de forma implícita que se utiliza para acceder a los valores, los `Pandas Series` tienen un índice explícito asociado a los valores.
#
# * El `index` (índice) no necesita ser un entero. Podemos usar `strings` (cadenas de texto).

# %%
# Creamos un vector de Numpy con valores del 5 al 20, con un paso de 2:
claudia = np.arange(5, 21, 2)
claudia
# Out:
# array([ 5,  7,  9, 11, 13, 15, 17, 19])

# %%
# Convertimos el vector de Numpy a una Serie de Pandas, con un índice personalizado:
# Ahora la serie es de 3 en 3, y el índice es un nombre de persona.
math = pd.Series( np.arange(5.,21.,3.) , ['joyce','jeremy','ivan','marcy','daniel','franclin'])
math
# Out:
# joyce        5.0
# jeremy       8.0
# ivan        11.0
# marcy       14.0
# daniel      17.0
# franclin    20.0
# dtype: float64

# %%
# Creamos una serie del 5 al 15, de 3 en 3, con un índice personalizado:
info = np.arange(5 , 15 ,3.)
index_info =  ['joyce','jeremy','ivan','marcy']

# %%
# De los objetos creados anteriormente, podemos crear una Serie de Pandas con un índice personalizado y un nombre para la Serie:
# Students sería el nombre de la Serie, y el índice es el nombre de cada estudiante.
math_2 = pd.Series(  info , index_info,  name = "Students")
math_2
# Out:
# joyce      5.0
# jeremy     8.0
# ivan      11.0
# marcy     14.0
# Name: Students, dtype: float64

# %% [markdown]
# ## <a id='1.4.'>1.4. Indexar</a>
#
# * Indexar (o la indexación) en `Pandas` significa simplemente seleccionar filas y columnas particulares de datos de un DataFrame.
# * También puede conocerse como Selección de Subconjuntos.

# %%
# Veamos a data y population:
print(data)
print(population)
# Out:
# 0    1.0
# 1    1.5
# 2    2.0
# 3    2.5
# 4    3.0
# dtype: float64
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64

# %%
data[1]
# Out:
# 1.5

# %%
# En número, si quiero ir hasta un índice particular, tengo que hacer lo siguiente:
# Si quiero del 0 al 2, la indexación va hasta el 3.
# Siempre uno menos si estoy en números.
print( data[0:3] )
# Out:
# 0    1.0
# 1    1.5
# 2    2.0
# dtype: float64

# %%
population
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64

# %% [markdown]
# * `dtype` es el tipo de data, no el tipo de objeto.
# * Puede haber `int16`, `int32`, `int64` o `float64`. Eso importará cuando hagamos Deep Learning, cuando involucremos al decimal 20.

# %%
# Cuando es texto, la indexación sí incluye el último elemento
print( population['Texas':'Florida'] )
# Out:
# Texas       26448193
# New York    19651127
# Florida     19552860
# dtype: int64

# %% [markdown]
# | Método 	| Definición 	|
# | --- 	| --- 	|
# | loc() 	|Obtiene filas (y/o columnas) con etiquetas (labels) particulares.<br> Acepta valores booleanos (`bool`) para el indexado. |
# | iloc() 	| Obtiene filas (y/o columnas) en posiciones de enteros (integer locations). <br> No acepta valores booleanos (`bool`) para el indexado.|

# %% [markdown]
# * Obtener el valor de Nueva York:

# %%
# loc(): Con una etiqueta particular, obtenemos el valor de la Serie. En este caso, la población de New York.
population.loc[ "New York" ]
# Out:
# 19651127

# %%
# iloc(): Con valores de indexación, obtenemos el valor de la Serie. En este caso, la población desde Texas hasta Illinois.
# Excluimos California por ser el primer elemento.
population.iloc[ 1:6 ]
# Out:
# Texas       26448193
# New York    19651127
# Florida     19552860
# Illinois    12882135
# dtype: int64

# %% [markdown]
# Replicate this excersice for `data` Series.

# %% [markdown]
# # <a id='2.'>II. `DataFrames`</a>
#
# * Un `DataFrame` es una colección de múltiples Series. Puede pensarse como un arreglo bidimensional (2D), donde cada fila es un punto de datos (datapoint) independiente y cada columna es una característica (feature) de los datos. Las filas están etiquetadas con un índice (al igual que en una Series) y las columnas están etiquetadas en el atributo columns.
#
# * Existen muchas formas diferentes de crear `DataFrames`: a partir de listas, diccionarios, etc.
#
# * Usaremos `Pandas` para trabajar con `DataFrames`.

# %% [markdown]
# ## <a id='2.1.'>2.1. Generación de `DataFrames`</a>
# ### De `lists` y `dict` a `DataFrame`:

# %%
# Notas de estudiantes (lista)
students = [ "Alejandro", "Pedro", "Ramiro", "Axel", "Juan" ]
math     = [ 15, 16, 10, 12, 13 ]
english  = [ 13, 9, 16, 14, 17 ]
art      = [ 12, 16, 15, 19, 10 ]

# Diccionario:
# A cada llave le asignamos una lista 
gradesA = {'Students':students, 'Math':math, 'English':english, 'Art':art}

# %%
gradesA
# Out:
# {'Students': ['Alejandro', 'Pedro', 'Ramiro', 'Axel', 'Juan'],
#  'Math': [15, 16, 10, 12, 13],
#  'English': [13, 9, 16, 14, 17],
#  'Art': [12, 16, 15, 19, 10]}

# %%
# Convertimos el diccionario en un DataFrame de Pandas:
gradesA1 = pd.DataFrame(gradesA)
gradesA1
# Out:
#     Students  Math  English  Art
# 0  Alejandro    15       13   12
# 1      Pedro    16        9   16
# 2     Ramiro    10       16   15
# 3       Axel    12       14   19
# 4       Juan    13       17   10

# %% [markdown]
# ## <a id='2.2.'>2.2. Indexing</a>
#
# * Podemos utilizar los mismos métodos que en las `Series`: `iloc` y `loc`, seleccionando tanto columnas como filas.

# %%
# Otras notas de estudiantes (lista)
students = [ "Gissela", "Daniel", "Andres", "Sandra", "Rosalyn" ]
math     = [ 16, 14, 17, 17, 17 ]
english  = [ 16, 17, 19, 18, 15 ]
art      = [ 11, 17, 13, 14, 17 ]

# Diccionario
diplomado = {'Students':students, 'Math':math, 'English':english, 'Art':art}

# DataFrame:
gradesA1 = pd.DataFrame( diplomado )
gradesA1
# Out:
#   Students  Math  English  Art
# 0  Gissela    16       16   11
# 1   Daniel    14       17   17
# 2   Andres    17       19   13
# 3   Sandra    17       18   14
# 4  Rosalyn    17       15   17

# %%
# MÉTODO loc(): Con valores de indexación, obtenemos el valor de la Serie.
# En este caso, seleccionamos las filas que van desde el 0 hasta el 3 y las columnas de "Art" y "Students"
# Recordar que loc es un método porque está al costado del objeto y no al costado del alias de la librería (pd como Pandas, por ejemplo).
gradesA1.loc[ 0:3 ,  ["Art", "Students"] ]
# Out:
#    Art Students
# 0   11  Gissela
# 1   17   Daniel
# 2   13   Andres
# 3   14   Sandra

# %%
# Ahora seleccionamos todas las filas (:) y las columnas "Students", "English" y "Art".
gradesA1.loc[ :, ["Students", "English", "Art"] ]
# Out:
#   Students  English  Art
# 0  Gissela       16   11
# 1   Daniel       17   17
# 2   Andres       19   13
# 3   Sandra       18   14
# 4  Rosalyn       15   17

# %% [markdown]
# ## <a id='2.3.'>2.3. Métodos Generales</a>

# %% [markdown]
# |Métodos|Descripción|
# |------|-----------|
# |columns()|Obtiene el nombre de las columnas.|
# |sort_values()|Ordena según los valores a lo largo de cualquiera de los ejes.|
# |sort_index()|Ordena según el índice.|
# |head()|Muestra las primeras N observaciones.|
# |drop( )| Elimina las entradas con la etiqueta o etiquetas especificadas.|
# |append( )| Concatena dos o más Series.|
# |drop_duplicates( )| Elimina los valores duplicados.|
# |dropna( ) |Elimina las entradas nulas.|
# |fillna( ) |Reemplaza las entradas nulas con un valor o estrategia especificada.|
# |reset_index( )| Convierte el índice en una columna.|
# |sample( ) |Extrae una entrada aleatoria.|
# |shift( ) |Desplaza el índice.|
# |unique( ) |Devuelve los valores únicos.|

# %%
# Veamos otro ejemplo, ahora con diccionarios:
deps = {
        'dep' : ['Lima', 'Piura', 'Tumbes', 'Cuzco', 'Ica', 'Puno'],
        'year': [ 2000, 2001, 2002, 2001, 2002, 2003 ],
        'pop' : [ 1.5, 1.7, 3.6, 2.4, 2.9, 3.2 ] 
        }
dep1 = pd.DataFrame( deps )
dep1
# Out:
#       dep  year  pop
# 0    Lima  2000  1.5
# 1   Piura  2001  1.7
# 2  Tumbes  2002  3.6
# 3   Cuzco  2001  2.4
# 4     Ica  2002  2.9
# 5    Puno  2003  3.2

# %% [markdown]
# * El método `sort_values` tiene muchos argumentos: `inlpace` es uno de ellos y por default es `False`.
# * Por ello es importante explicitar cuando lo queremos `True`, para que los cambios tengan efecto en la data ahí mismo.
# * `inplace` = `True` quiere decir que haga efectivo los cambios ahí mismo y que chanques la data. Es razonable para no crear más objetos.

# %%
# Quiero ordenarlo según la variable "dep" (departamento): usamos el método sort_values para ordenar.
# Se ordena alfabéticamente porque dep es chr, si fuera variable int se ordena de menor a mayor.
dep1.sort_values( ["dep"] , inplace=True, )
dep1
# Out:
#       dep  year  pop
# 3   Cuzco  2001  2.4
# 4     Ica  2002  2.9
# 0    Lima  2000  1.5
# 1   Piura  2001  1.7
# 5    Puno  2003  3.2
# 2  Tumbes  2002  3.6

# %%
# ascending=False: ordena de mayor a menor, y en letras, de la Z a la A.
dep1.sort_values( ["dep"], inplace= True, ignore_index=True, ascending=False)
dep1
# Out:
#       dep  year  pop
# 0  Tumbes  2002  3.6
# 1    Puno  2003  3.2
# 2   Piura  2001  1.7
# 3    Lima  2000  1.5
# 4     Ica  2002  2.9
# 5   Cuzco  2001  2.4

# %%
# Recordemos el DataFrame de notas de estudiantes:
gradesA1
# Out:
#   Students  Math  English  Art
# 0  Gissela    16       16   11
# 1   Daniel    14       17   17
# 2   Andres    17       19   13
# 3   Sandra    17       18   14
# 4  Rosalyn    17       15   17

# %% [markdown]
# * Operaciones con DataFrames: Veamos los métodos en acción.

# %%
# Suma de las columnas "Math" y "English" del DataFrame gradesA1:
gradesA1["Math"] + gradesA1["English"]
# Out:
# 0    32
# 1    31
# 2    36
# 3    35
# 4    32
# dtype: int64

# %%
# Nueva columna
gradesA1['promedio'] = ( gradesA1['Math'] + gradesA1['English'] + gradesA1['Art'] ) / 3
gradesA1
# Out:
#   Students  Math  English  Art   promedio
# 0  Gissela    16       16   11  14.333333
# 1   Daniel    14       17   17  16.000000
# 2   Andres    17       19   13  16.333333
# 3   Sandra    17       18   14  16.333333
# 4  Rosalyn    17       15   17  16.333333

# %%
# drop: Eliminar columnas o filas de un DataFrame 
# El parámetro axis=1 indica que buscamos una columna (axis=0 sería para filas).
# inplace = True significa que los cambios se aplican directamente al DataFrame original, sin necesidad de crear una copia.
gradesA1.drop("promedio", axis=1, inplace=True)
gradesA1
# Out:
#   Students  Math  English  Art
# 0  Gissela    16       16   11
# 1   Daniel    14       17   17
# 2   Andres    17       19   13
# 3   Sandra    17       18   14
# 4  Rosalyn    17       15   17

# %%
# rename: Cambiar el nombre de una columna en un DataFrame
gradesA1.rename(columns={"Students": "Estudiantes"}, inplace=True)
gradesA1
# Out:
#   Estudiantes  Math  English  Art
# 0     Gissela    16       16   11
# 1      Daniel    14       17   17
# 2      Andres    17       19   13
# 3      Sandra    17       18   14
# 4     Rosalyn    17       15   17

# %%
# iloc(): Con valores de indexación, obtenemos el valor de la Serie. 
# En este caso, el promedio de las columnas de los cursos en las posiciones 2, 3 y 4 (Math, English y Art) para cada estudiante.
# Mean Math & English
gradesA1.iloc[:, 2:4].mean(axis=1)
# Out:
# 0    13.5
# 1    17.0
# 2    16.0
# 3    16.0
# 4    16.0
# dtype: float64

# %%
# head: Mostrar las primeras filas de un DataFrame. Por defecto, muestra las primeras 5 filas, pero podemos especificar cuántas queremos ver.
gradesA1.head(4)
# Out:
#   Estudiantes  Math  English  Art
# 0     Gissela    16       16   11
# 1      Daniel    14       17   17
# 2      Andres    17       19   13
# 3      Sandra    17       18   14

# %% [markdown]
# * Renombramos de nuevo la columna **Estudiantes** para no tener problemas con el código que sigue:
# * Agregar nuevos datos con el método `concat()` de `Pandas`, usando las mismas columnas que el DataFrame original.

# %%
# MÉTODO rename
# Formato: .rename(columns={"Columna antigua": "Columna nueva"}, inplace=True)
gradesA1.rename(columns={"Estudiantes": "Students"}, inplace=True)
gradesA1
# Out:
#   Students  Math  English  Art
# 0  Gissela    16       16   11
# 1   Daniel    14       17   17
# 2   Andres    17       19   13
# 3   Sandra    17       18   14
# 4  Rosalyn    17       15   17

# %%
# Agregamos nueva data: gradesA2
# Nuevos estudiantes y sus notas en Math, English y Art
students = [ "Rebeca", "Xavi", "Cristiano", "Ronaldo", "Leo" ]
math     = [ 15, 18, 14, 7, 10 ]
english  = [ 18, 9, 11, 12, 20 ]
art      = [ 10, 16, 20, 19, 5 ]

# Dictionary
grades_A2 = {'Students':students, 'Math':math, 'English':english, 'Art':art}

# Convertimos el diccionario en un DataFrame de Pandas:
gradesA2 = pd.DataFrame( grades_A2 )
print( gradesA2 , "\n")
# Out:
#     Students  Math  English  Art
# 0     Rebeca    15       18   10
# 1       Xavi    18        9   16
# 2  Cristiano    14       11   20
# 3    Ronaldo     7       12   19
# 4        Leo    10       20    5

# %%
gradesA1
# Out:
#   Students  Math  English  Art
# 0  Gissela    16       16   11
# 1   Daniel    14       17   17
# 2   Andres    17       19   13
# 3   Sandra    17       18   14
# 4  Rosalyn    17       15   17

# %%
gradesA2
# Out:
#     Students  Math  English  Art
# 0     Rebeca    15       18   10
# 1       Xavi    18        9   16
# 2  Cristiano    14       11   20
# 3    Ronaldo     7       12   19
# 4        Leo    10       20    5

# %% [markdown]
# * Unimos ambos datos:

# %%
pd.concat( [gradesA1, gradesA2] , ignore_index=True)
# Out:
#     Students  Math  English  Art
# 0    Gissela    16       16   11
# 1     Daniel    14       17   17
# 2     Andres    17       19   13
# 3     Sandra    17       18   14
# 4    Rosalyn    17       15   17
# 5     Rebeca    15       18   10
# 6       Xavi    18        9   16
# 7  Cristiano    14       11   20
# 8    Ronaldo     7       12   19
# 9        Leo    10       20    5

# %%
# Aquí vemos qué sucede si no colocamos ignore_index=True. 
# El índice se mantiene, y se repiten los índices de 0 a 4.
grades_total = pd.concat([gradesA1, gradesA2])
grades_total
# Out:
#     Students  Math  English  Art
# 0    Gissela    16       16   11
# 1     Daniel    14       17   17
# 2     Andres    17       19   13
# 3     Sandra    17       18   14
# 4    Rosalyn    17       15   17
# 0     Rebeca    15       18   10
# 1       Xavi    18        9   16
# 2  Cristiano    14       11   20
# 3    Ronaldo     7       12   19
# 4        Leo    10       20    5

# %%
# Ahora sí, con ignore_index=True, el índice se reinicia y se asigna un nuevo índice a cada fila del DataFrame resultante.
# copy() es para crear una copia del DataFrame resultante y evitar advertencias de Pandas sobre la modificación de un DataFrame que podría estar vinculado a otro.
grades_total = pd.concat([gradesA1, gradesA2], ignore_index=True).copy()
grades_total
# Out:
#     Students  Math  English  Art
# 0    Gissela    16       16   11
# 1     Daniel    14       17   17
# 2     Andres    17       19   13
# 3     Sandra    17       18   14
# 4    Rosalyn    17       15   17
# 5     Rebeca    15       18   10
# 6       Xavi    18        9   16
# 7  Cristiano    14       11   20
# 8    Ronaldo     7       12   19
# 9        Leo    10       20    5

# %% [markdown]
# * Si hay una columna con datos parciales en una columna, aparecerá "NaN" en los valores faltantes.

# %%
# Veamos otro ejemplo de DataFrame, ahora con información de autos:
cars = pd.DataFrame({
            'brands'    : [ 'hyundai', 'hyundai', 'kia', 'kia', 'kia' ] ,
            'model'     : [ 'sedan', 'sedan', 'sedan', 'truck', 'truck' ] ,
            'passengers': [ 4, 4, 5, 6, 8 ]
            })
cars
# Out:
#     brands  model  passengers
# 0  hyundai  sedan           4
# 1  hyundai  sedan           4
# 2      kia  sedan           5
# 3      kia  truck           6
# 4      kia  truck           8

# %%
# Eliminamos duplicados de las columnas "brands" y "model" del DataFrame cars, dejando solo la primera ocurrencia de cada combinación única de estas columnas.
# Se quedan las combinaciones únicas de "brands" y "model": 
# * 0 hyuandai sedan
# * 2 kia sedan
# * 3 kia truck
cars.drop_duplicates(subset = [ "brands", "model"])
# Out:
#     brands  model  passengers
# 0  hyundai  sedan           4
# 2      kia  sedan           5
# 3      kia  truck           6

# %%
# Si queremos algo más habitual, lo mejor es restringir por columna.
# Usaremos "brands", por lo que ahora solo nos debe mostrar elementos únicos de la columna "brands"
cars_subset = cars.drop_duplicates(subset = [ 'brands' ])
cars_subset
# Out:
#     brands  model  passengers
# 0  hyundai  sedan           4
# 2      kia  sedan           5

# %%
# Recordemos el DataFrame de notas de estudiantes:
grades_total
# Out:
#     Students  Math  English  Art
# 0    Gissela    16       16   11
# 1     Daniel    14       17   17
# 2     Andres    17       19   13
# 3     Sandra    17       18   14
# 4    Rosalyn    17       15   17
# 5     Rebeca    15       18   10
# 6       Xavi    18        9   16
# 7  Cristiano    14       11   20
# 8    Ronaldo     7       12   19
# 9        Leo    10       20    5

# %%
# dropna
print( grades_total )
# Out:
#     Students  Math  English  Art
# 0    Gissela    16       16   11
# 1     Daniel    14       17   17
# 2     Andres    17       19   13
# 3     Sandra    17       18   14
# 4    Rosalyn    17       15   17
# 5     Rebeca    15       18   10
# 6       Xavi    18        9   16
# 7  Cristiano    14       11   20
# 8    Ronaldo     7       12   19
# 9        Leo    10       20    5

# %%
# MÉTODO dropna(): Elimina las filas que contienen valores nulos (NaN) en el DataFrame.
# Sin embargo, no hay NAs, por lo que la columna permanece igual.
grades_total.dropna()
# Out:
#     Students  Math  English  Art
# 0    Gissela    16       16   11
# 1     Daniel    14       17   17
# 2     Andres    17       19   13
# 3     Sandra    17       18   14
# 4    Rosalyn    17       15   17
# 5     Rebeca    15       18   10
# 6       Xavi    18        9   16
# 7  Cristiano    14       11   20
# 8    Ronaldo     7       12   19
# 9        Leo    10       20    5

# %%
# MÉTODO sample(): Devuelve una muestra aleatoria de filas del DataFrame.
grades_total.sample( n=3 )
# Out:
#     Students  Math  English  Art
# 9        Leo    10       20    5
# 7  Cristiano    14       11   20
# 4    Rosalyn    17       15   17

# %%
# Ahora una muestra de 5 filas:
print( grades_total.sample(n = 5) )
# Out:
#   Students  Math  English  Art
# 5   Rebeca    15       18   10
# 9      Leo    10       20    5
# 1   Daniel    14       17   17
# 3   Sandra    17       18   14
# 4  Rosalyn    17       15   17

# %%
# Ahora una muestra del 20% de las filas del DataFrame, con una semilla aleatoria para reproducibilidad.
# La elección es aleatoria, por lo que cada vez que ejecutemos el código obtendremos resultados diferentes.
print( grades_total.sample( frac = 0.2, random_state=123 ), "\n")
# Out:
#   Students  Math  English  Art
# 4  Rosalyn    17       15   17
# 0  Gissela    16       16   11

# %% [markdown]
# ## <a id='2.4.'>2.4. Importando datos: GitHub</a>

# %% [markdown]
# **INNOVATION GRAPH:**
# * Contiene los repositorios por temática y país alrededor del mundo.

# %%
# URL del archivo CSV hospedado en GitHub (hacemos click en "Raw")
# Repositorios de Github de la página de Innovation Graph:
url = "https://raw.githubusercontent.com/github/innovationgraph/refs/heads/main/data/repositories.csv"

# Carga directa desde la URL
df = pd.read_csv(url)

# Muestra las primeras filas del DataFrame
df
# Out:
#       repositories iso2_code  year  quarter
# 0         30669781        US  2020        1
# 1         20179087        CN  2020        1
# 2         17912888        EU  2020        1
# 3          9254535        IN  2020        1
# 4          4171705        GB  2020        1
# ...            ...       ...   ...      ...
# 5630           231        AQ  2026        1
# 5631           219        MH  2026        1
# 5632           196        IO  2026        1
# 5633           161        PM  2026        1
# 5634           142        MS  2026        1
#
# [5635 rows x 4 columns]

# %%
# Renombrar columnas:
df.rename(columns={"repositories": "num_repos"}, inplace=True)
df
# Out:
#       num_repos iso2_code  year  quarter
# 0      30669781        US  2020        1
# 1      20179087        CN  2020        1
# 2      17912888        EU  2020        1
# 3       9254535        IN  2020        1
# 4       4171705        GB  2020        1
# ...         ...       ...   ...      ...
# 5630        231        AQ  2026        1
# 5631        219        MH  2026        1
# 5632        196        IO  2026        1
# 5633        161        PM  2026        1
# 5634        142        MS  2026        1
#
# [5635 rows x 4 columns]

# %%
# Seleccionar solo Perú:
# La idea es seleccionar la columna y colocar los valores que quiero encontrar.
# Para eso se crearon booleanos donde se seleccionarán los valores TRUE
# Traducción: En la base df, quiero los valores del df que son PE
df[df["iso2_code"] == "PE"]
# Out:
#       num_repos iso2_code  year  quarter
# 49       356948        PE  2020        1
# 263      391794        PE  2020        2
# 480      424103        PE  2020        3
# 698      456011        PE  2020        4
# 916      485312        PE  2021        1
# 1136     527124        PE  2021        2
# 1356     567869        PE  2021        3
# 1580     609800        PE  2021        4
# 1803     652580        PE  2022        1
# 2025     704939        PE  2022        2
# 2247     753704        PE  2022        3
# 2472     805264        PE  2022        4
# 2696     852209        PE  2023        1
# 2923     913172        PE  2023        2
# 3150     969559        PE  2023        3
# 3378    1021424        PE  2023        4
# 3604    1070001        PE  2024        1
# 3832    1138879        PE  2024        2
# 4058    1207493        PE  2024        3
# 4289    1280517        PE  2024        4
# 4518    1336842        PE  2025        1
# 4748    1439611        PE  2025        2
# ...

# %%
# Si quiero dos países: Perú y Argentina
# Usamos un "o" (or) y paréntesis para cada condición
df[ (df["iso2_code"] == "PE") | (df["iso2_code"] == "AR") ]
# Out:
#       num_repos iso2_code  year  quarter
# 31       608445        AR  2020        1
# 49       356948        PE  2020        1
# 244      670189        AR  2020        2
# 263      391794        PE  2020        2
# 460      737110        AR  2020        3
# 480      424103        PE  2020        3
# 678      802976        AR  2020        4
# 698      456011        PE  2020        4
# 898      867545        AR  2021        1
# 916      485312        PE  2021        1
# 1118     965194        AR  2021        2
# 1136     527124        PE  2021        2
# 1340    1070330        AR  2021        3
# 1356     567869        PE  2021        3
# 1563    1180271        AR  2021        4
# 1580     609800        PE  2021        4
# 1785    1312481        AR  2022        1
# 1803     652580        PE  2022        1
# 2007    1514018        AR  2022        2
# 2025     704939        PE  2022        2
# 2231    1692345        AR  2022        3
# 2247     753704        PE  2022        3
# ...

# %%
# Quiero los códigos de los países de Sudamérica, que son: PE, AR, BR, CL, CO, EC, GY, PY, SR, UY y VE.
# Usamos el método isin() para seleccionar los valores que están en la lista de países sud
# Creamos lista:
south_america_codes = [
    "AR", "BO", "BR", "CL", "CO", "EC",
    "GY", "PY", "PE", "SR", "UY", "VE", "GF"
]

# Filter DataFrame
df_south_america = df[df["iso2_code"].isin(south_america_codes)]
df_south_america
# Out:
#       num_repos iso2_code  year  quarter
# 5       3602025        BR  2020        1
# 26       678828        CO  2020        1
# 31       608445        AR  2020        1
# 49       356948        PE  2020        1
# 50       353627        CL  2020        1
# ...         ...       ...   ...      ...
# 5493     309547        UY  2026        1
# 5508     163202        PY  2026        1
# 5576       9645        GY  2026        1
# 5582       7373        SR  2026        1
# 5594       4194        GF  2026        1
#
# [325 rows x 4 columns]

# %%
# Queremos saber cuántas columnas y filas hay en DataFrame de países de Sudamérica:
df_south_america.shape
# Out:
# (325, 4)

# %%
# Podemos extraer columnas específicas
# Van dos corchetes porque estamos extrayendo varias columnas, y no una sola. Si fuera una sola columna, bastaría con un solo corchete.
# No chancamos la información, solo nos muestra el resultado.
# El corchete indica que es una lista.
df_south_america[["quarter", "year"]]
# Out:
#       quarter  year
# 5           1  2020
# 26          1  2020
# 31          1  2020
# 49          1  2020
# 50          1  2020
# ...       ...   ...
# 5493        1  2026
# 5508        1  2026
# 5576        1  2026
# 5582        1  2026
# 5594        1  2026
#
# [325 rows x 2 columns]

# %%
# Eso implica que podemos reordenar las columnas:
# Con el siglo igual, ahora sí chanco el df
df_south_america = df_south_america[["iso2_code", "year", "quarter", "num_repos"]]
df_south_america
# Out:
#      iso2_code  year  quarter  num_repos
# 5           BR  2020        1    3602025
# 26          CO  2020        1     678828
# 31          AR  2020        1     608445
# 49          PE  2020        1     356948
# 50          CL  2020        1     353627
# ...        ...   ...      ...        ...
# 5493        UY  2026        1     309547
# 5508        PY  2026        1     163202
# 5576        GY  2026        1       9645
# 5582        SR  2026        1       7373
# 5594        GF  2026        1       4194
#
# [325 rows x 4 columns]

# %%
# El index sigue siendo caótico, desordenado. Procedemos a ordenarlo y reiniciar el índice:
df_south_america.reset_index(inplace=True)
df_south_america
# Out:
#      index iso2_code  year  quarter  num_repos
# 0        5        BR  2020        1    3602025
# 1       26        CO  2020        1     678828
# 2       31        AR  2020        1     608445
# 3       49        PE  2020        1     356948
# 4       50        CL  2020        1     353627
# ..     ...       ...   ...      ...        ...
# 320   5493        UY  2026        1     309547
# 321   5508        PY  2026        1     163202
# 322   5576        GY  2026        1       9645
# 323   5582        SR  2026        1       7373
# 324   5594        GF  2026        1       4194
#
# [325 rows x 5 columns]

# %%
# Podemos eliminar o mantener la nueva columna index creada
# Decidimos eliminarla porque no es necesaria y solo ocupa espacio.
df_south_america.drop(columns=["index"], inplace=True)
df_south_america
# Out:
#     iso2_code  year  quarter  num_repos
# 0          BR  2020        1    3602025
# 1          CO  2020        1     678828
# 2          AR  2020        1     608445
# 3          PE  2020        1     356948
# 4          CL  2020        1     353627
# ..        ...   ...      ...        ...
# 320        UY  2026        1     309547
# 321        PY  2026        1     163202
# 322        GY  2026        1       9645
# 323        SR  2026        1       7373
# 324        GF  2026        1       4194
#
# [325 rows x 4 columns]

# %%
# Queremos ordenar el DataFrame por las columnas "iso2_code", "year" y "quarter" en orden ascendente.
# Como si fuera una serie de tiempo: primero por país, luego por año y finalmente por trimestre.
df_south_america = df_south_america.sort_values(
    by=["iso2_code", "year", "quarter"],
    ascending=[True, True, True]
)
df_south_america
# Out:
#     iso2_code  year  quarter  num_repos
# 2          AR  2020        1     608445
# 15         AR  2020        2     670189
# 28         AR  2020        3     737110
# 41         AR  2020        4     802976
# 54         AR  2021        1     867545
# ..        ...   ...      ...        ...
# 266        VE  2025        1     380857
# 279        VE  2025        2     403230
# 292        VE  2025        3     421440
# 305        VE  2025        4     438426
# 318        VE  2026        1     460235
#
# [325 rows x 4 columns]

# %% [markdown]
# * Es importante tener en cuenta que la base debe estar balanceada.
# * Es decir, que todos los quearter tengan dato. Si no sucede, hablar con el encargado. Quizás sea conveniente colocar 0 o NaN.

# %%
# Quiero ver los valores nulos (NaN) en la columna "num_repos" del DataFrame df_south_america. 
# Esto me permitirá identificar si hay registros sin información.
df_south_america[df_south_america.num_repos.isna() ]
# Out:
# Empty DataFrame
# Columns: [iso2_code, year, quarter, num_repos]
# Index: []

# %%
# El índice volvió a molestarnos (porque se reordenó el DataFrame). Procedemos a ordenarlo y reiniciar el índice:
df_south_america.reset_index(inplace=True)
df_south_america
# Out:
#      level_0  index iso2_code  year  quarter  num_repos
# 0          0      2        AR  2020        1     608445
# 1          1     15        AR  2020        2     670189
# 2          2     28        AR  2020        3     737110
# 3          3     41        AR  2020        4     802976
# 4          4     54        AR  2021        1     867545
# ..       ...    ...       ...   ...      ...        ...
# 320      320    266        VE  2025        1     380857
# 321      321    279        VE  2025        2     403230
# 322      322    292        VE  2025        3     421440
# 323      323    305        VE  2025        4     438426
# 324      324    318        VE  2026        1     460235
#
# [325 rows x 6 columns]

# %%
# Eliminamos el índice anterior y el que se creó al reiniciar el índice, ya que no es necesario y solo ocupa espacio.
# Columnas level_0 e index:
df_south_america.drop(columns=["level_0", "index"], inplace=True)
df_south_america
# Out:
#     iso2_code  year  quarter  num_repos
# 0          AR  2020        1     608445
# 1          AR  2020        2     670189
# 2          AR  2020        3     737110
# 3          AR  2020        4     802976
# 4          AR  2021        1     867545
# ..        ...   ...      ...        ...
# 320        VE  2025        1     380857
# 321        VE  2025        2     403230
# 322        VE  2025        3     421440
# 323        VE  2025        4     438426
# 324        VE  2026        1     460235
#
# [325 rows x 4 columns]

# %%
# Quiero ver el tipo de datos de las columnas:
df_south_america.dtypes
# Out:
# iso2_code    object
# year          int64
# quarter       int64
# num_repos     int64
# dtype: object

# %%
# Podemos cambiar el tipo de datos de iso2_code a string (str) para asegurarnos de que se trate como texto y no como un número. 
# Esto es útil si queremos realizar operaciones de texto o evitar problemas de interpretación de datos.
df_south_america["iso2_code"] = df_south_america["iso2_code"].astype(str)
df_south_america.dtypes
# Out:
# iso2_code    object
# year          int64
# quarter       int64
# num_repos     int64
# dtype: object

# %%
# Exportamos a formato csv en la misma carpeta del notebook:
# Guarda el DataFrame en la carpeta 'data'
df_south_america.to_csv("data/south_america_repositorios.csv", index=False)

# %% [markdown]
# ## <a id='2.5.'>2.5. Importando datos: ENAPRES</a>

# %% [markdown]
# |Método|Descripción|
# |------|-----------|
# |read_excel( )|Lee un archivo Excel y lo convierte en un DataFrame.|
# |to_csv( )| Escribe el índice y los registros en un archivo CSV|
# |read_csv( )| Lee un archivo CSV y lo convierte en un DataFrame.|
# |to_json( )| Convierte el objeto en una cadena de texto JSON.|
# |to_pickle( )| Serializa el objeto y lo almacena en un archivo externo.|
# |to_sql( )| Escribe los datos del objeto en una base de datos SQL activa.|
# |read_html( )| Lee una tabla de una página HTML y la convierte en un DataFrame.|
# |read_spss( )| Lee un archivo SPSS y lo convierte en un DataFrame.|

# %% [markdown]
# * La Encuesta Nacional de Programas Presupuestales (ENAPRES) se lleva a cabo desde el año 2010 en las zonas urbanas y rurales de los 24 departamentos y la Provincia Constitucional del Callao, como parte de las investigaciones realizadas por el Instituto Nacional de Estadística e Informática (INEI) en coordinación con el Ministerio de Economía y Finanzas (MEF) y los diversos ministerios y organismos del sector público.

# %%
import pandas as pd
import os

# %% [markdown]
# **DIRECCIONES RELATIVAS**
#
# * Descargar el archivo correspondiente
# * Usar **pwd** para saber su ubicación actual
# * Dos puntos son un click para atrás seguido de un slash, junto con la nueva ruta que le corresponde.

# %%
# Descargamos el archivo SPSS desde la web del INEI
# La ruta del archivo se construye utilizando os.path.join para asegurar la compatibilidad entre sistemas operativos
ruta_spss = os.path.join("data", "CAP_100_URBANO_RURAL_3.sav")

# %%
# Leemos el archivo SPSS usando Pandas
enapres2020_1 = pd.read_spss(ruta_spss)

# Mostramos las primeras 5 filas para verificar que cargó bien
enapres2020_1.head()
# Out:
#    PER  ANIO MES CONGLOMERADO NSELV   TSELV VIVREM  NUMVIVREM    AREA CCDD  \
# 0  2.0  2020  07        04046  0046   Rural    0.0        NaN   RURAL   14
# 1  2.0  2020  09        03981  0120  Urbano    0.0        NaN  URBANO   14
# 2  2.0  2020  09        03981  0189  Urbano    0.0        NaN  URBANO   14
# 3  2.0  2020  09        03981  0189  Urbano    0.0        NaN  URBANO   14
# 4  2.0  2020  07        04046  0043   Rural    0.0        NaN   RURAL   14
#
#    ... P189_5 P189_6 P189_7 P189_8 P189_8_O REGIONNATU    ESTRATO  \
# 0  ...    NaN    NaN    NaN    NaN               COSTA        NaN
# 1  ...    NaN    NaN    NaN    NaN               COSTA  Estrato D
# 2  ...    NaN    NaN    NaN    NaN               COSTA  Estrato D
# 3  ...    NaN    NaN    NaN    NaN               COSTA  Estrato D
# 4  ...    NaN    NaN    NaN    NaN               COSTA        NaN
#
#          MOD_ENC     FACTOR  FACTOR_CALIBRADO
# 0  No Presencial  121.27014               NaN
# ...

# %%
# Variables
enapres2020_1.attrs
# Out:
# {'column_names': ['PER',
#   'ANIO',
#   'MES',
#   'CONGLOMERADO',
#   'NSELV',
#   'TSELV',
#   'VIVREM',
#   'NUMVIVREM',
#   'AREA',
#   'CCDD',
#   'NOMBREDD',
#   'CCPP',
#   'NOMBREPP',
#   'CCDI',
#   'NOMBREDI',
#   'VIVIENDA',
#   'TOT_HOGAR',
#   'HOGAR',
#   'RESFIN',
#   'P100_C',
#   'P101',
#   'P101_O',
#   'P102A',
#   'P102A_O',
#   'P103',
#   'P103_O',
#   'P104B',
#   'P104B_O',
#   'P105',
#   'P106',
#   'P106_O',
#   'P106A',
#   'P107',
#   'P107A',
#   'P107A_O',
#   'P107B',
#   'P107B_O',
#   'P107C',
#   'P108',
#   'P108_1',
#   'P108_1_O',
#   'P108A',
#   'P108B',
#   'P108B_O',
#   'P109',
#   'P110A',
#   'P110AA',
#   'P110AB',
#   'P110AC',
#   'P111A',
#   'P111AA',
#   'P111AB_HORAS',
#   'P111AB_MINUTOS',
#   'P112_1',
#   'P113_1',
#   'P113A_1',
#   'P113B_1_1',
#   'P113B_1_1_ENT',
#   'P113B_1_2',
#   'P113B_1_2_ENT',
#   'P113B_1_3',
#   'P113B_1_3_ENT',
#   'P113B_1_3_O',
#   'P117_1',
#   'P118_1',
#   'P118_1_O',
#   'P119_1',
# ...

# %%
# adding labels to variables
enapres2020_1.attrs[ 'value_labels' ] = labels_enapres2020_1
enapres2020_1.attrs[ 'var_labels' ] = metadata.varLabels
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 # adding labels to variables
# ----> 2 enapres2020_1.attrs[ 'value_labels' ] = labels_enapres2020_1
#       3 enapres2020_1.attrs[ 'var_labels' ] = metadata.varLabels
#
# NameError: name 'labels_enapres2020_1' is not defined

# %%
enapres2020_1
# Out:
#        PER  ANIO MES CONGLOMERADO NSELV   TSELV VIVREM  NUMVIVREM    AREA  \
# 0      2.0  2020  07        04046  0046   Rural    0.0        NaN   RURAL
# 1      2.0  2020  09        03981  0120  Urbano    0.0        NaN  URBANO
# 2      2.0  2020  09        03981  0189  Urbano    0.0        NaN  URBANO
# 3      2.0  2020  09        03981  0189  Urbano    0.0        NaN  URBANO
# 4      2.0  2020  07        04046  0043   Rural    0.0        NaN   RURAL
# ...    ...   ...  ..          ...   ...     ...    ...        ...     ...
# 42148  2.0  2020  05        51489  0073  Urbano    0.0        NaN  URBANO
# 42149  2.0  2020  05        51489  0079  Urbano    0.0        NaN  URBANO
# 42150  3.0  2020  08        51548  0026  Urbano    0.0        NaN  URBANO
# 42151  3.0  2020  08        51548  0046  Urbano    0.0        NaN  URBANO
# 42152  3.0  2020  08        51548  0066  Urbano    0.0        NaN  URBANO
#
#       CCDD  ... P189_5 P189_6 P189_7 P189_8 P189_8_O REGIONNATU  \
# ...

# %%
enapres2020_1.attrs[ 'value_labels' ]
# Out:
# {'labels0': {1.0: 'Urbano', 4.0: 'SemiRural', 5.0: 'Rural'},
#  'labels1': {1.0: 'Si', 2.0: 'No'},
#  'labels2': {1.0: 'URBANO', 2.0: 'RURAL'},
#  'labels3': {1.0: 'Completa', 2.0: 'Incompleta'},
#  'labels4': {1.0: 'Casa independiente',
#   2.0: 'Departamento en edificio',
#   3.0: 'Vivienda en quinta',
#   4.0: 'Vivienda en casa de vecindad (callejón, solar o corralón)',
#   5.0: 'Choza o cabaña',
#   6.0: 'Vivienda improvisada',
#   7.0: 'Local no destinado para habitación humana',
#   8.0: 'Otro(Especifique)'},
#  'labels5': {1.0: 'Ladrillo o bloque de cemento?',
#   2.0: 'Piedra o sillar con cal o cemento?',
#   3.0: 'Adobe?',
#   4.0: 'Tapia?',
#   5.0: 'Quincha (caña con barro)?',
#   6.0: 'Piedra con barro?',
#   7.0: ' Madera (pona, tornillo, etc.)?',
#   8.0: 'Tripley/ Calamina/ Estera?',
#   9.0: 'Otro material?'},
#  'labels6': {1.0: '¿Parquet o madera pulida?',
#   2.0: '¿Láminas asfálticas, vinílicos o similares?',
#   3.0: '¿Losetas, terrazos o similares?',
# ...

# %% [markdown]
# ### 3.3.5. <a id='3.3.5'>Filtering data</a>

# %%
enapres2020_1.AREA == "RURAL"
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 42148    False
# 42149    False
# 42150    False
# 42151    False
# 42152    False
# Name: AREA, Length: 42153, dtype: bool

# %%
enapres2020_1.shape
# Out:
# (42153, 491)

# %%
enapres2020_1.loc[ enapres2020_1.AREA == 'URBANO',  :  ]
# Out:
#        PER  ANIO MES CONGLOMERADO NSELV   TSELV VIVREM  NUMVIVREM    AREA  \
# 1      2.0  2020  09        03981  0120  Urbano    0.0        NaN  URBANO
# 2      2.0  2020  09        03981  0189  Urbano    0.0        NaN  URBANO
# 3      2.0  2020  09        03981  0189  Urbano    0.0        NaN  URBANO
# 6      2.0  2020  09        06703  0037  Urbano    0.0        NaN  URBANO
# 7      2.0  2020  09        03981  0057  Urbano    0.0        NaN  URBANO
# ...    ...   ...  ..          ...   ...     ...    ...        ...     ...
# 42148  2.0  2020  05        51489  0073  Urbano    0.0        NaN  URBANO
# 42149  2.0  2020  05        51489  0079  Urbano    0.0        NaN  URBANO
# 42150  3.0  2020  08        51548  0026  Urbano    0.0        NaN  URBANO
# 42151  3.0  2020  08        51548  0046  Urbano    0.0        NaN  URBANO
# 42152  3.0  2020  08        51548  0066  Urbano    0.0        NaN  URBANO
#
#       CCDD  ... P189_5 P189_6 P189_7 P189_8 P189_8_O REGIONNATU  \
# ...

# %%
# select observations
# when we create a sample from our data, copy the object.
df_urban_main = enapres2020_1.loc[ enapres2020_1.AREA == 'URBANO', : ]
df_urban_main
# Out:
#        PER  ANIO MES CONGLOMERADO NSELV   TSELV VIVREM  NUMVIVREM    AREA  \
# 1      2.0  2020  09        03981  0120  Urbano    0.0        NaN  URBANO
# 2      2.0  2020  09        03981  0189  Urbano    0.0        NaN  URBANO
# 3      2.0  2020  09        03981  0189  Urbano    0.0        NaN  URBANO
# 6      2.0  2020  09        06703  0037  Urbano    0.0        NaN  URBANO
# 7      2.0  2020  09        03981  0057  Urbano    0.0        NaN  URBANO
# ...    ...   ...  ..          ...   ...     ...    ...        ...     ...
# 42148  2.0  2020  05        51489  0073  Urbano    0.0        NaN  URBANO
# 42149  2.0  2020  05        51489  0079  Urbano    0.0        NaN  URBANO
# 42150  3.0  2020  08        51548  0026  Urbano    0.0        NaN  URBANO
# 42151  3.0  2020  08        51548  0046  Urbano    0.0        NaN  URBANO
# 42152  3.0  2020  08        51548  0066  Urbano    0.0        NaN  URBANO
#
#       CCDD  ... P189_5 P189_6 P189_7 P189_8 P189_8_O REGIONNATU  \
# ...

# %%
df_urban_completa = df_urban_main.loc[ df_urban_main.RESFIN == 'Completa', : ]
df_urban_completa
# Out:
#        PER  ANIO MES CONGLOMERADO NSELV   TSELV VIVREM  NUMVIVREM    AREA  \
# 1      2.0  2020  09        03981  0120  Urbano    0.0        NaN  URBANO
# 2      2.0  2020  09        03981  0189  Urbano    0.0        NaN  URBANO
# 3      2.0  2020  09        03981  0189  Urbano    0.0        NaN  URBANO
# 6      2.0  2020  09        06703  0037  Urbano    0.0        NaN  URBANO
# 7      2.0  2020  09        03981  0057  Urbano    0.0        NaN  URBANO
# ...    ...   ...  ..          ...   ...     ...    ...        ...     ...
# 42148  2.0  2020  05        51489  0073  Urbano    0.0        NaN  URBANO
# 42149  2.0  2020  05        51489  0079  Urbano    0.0        NaN  URBANO
# 42150  3.0  2020  08        51548  0026  Urbano    0.0        NaN  URBANO
# 42151  3.0  2020  08        51548  0046  Urbano    0.0        NaN  URBANO
# 42152  3.0  2020  08        51548  0066  Urbano    0.0        NaN  URBANO
#
#       CCDD  ... P189_5 P189_6 P189_7 P189_8 P189_8_O REGIONNATU  \
# ...

# %%
enapres2020_1.loc[ (enapres2020_1.AREA == 'URBANO') & (enapres2020_1.RESFIN == 'Completa') ]
# Out:
#        PER  ANIO MES CONGLOMERADO NSELV   TSELV VIVREM  NUMVIVREM    AREA  \
# 1      2.0  2020  09        03981  0120  Urbano    0.0        NaN  URBANO
# 2      2.0  2020  09        03981  0189  Urbano    0.0        NaN  URBANO
# 3      2.0  2020  09        03981  0189  Urbano    0.0        NaN  URBANO
# 6      2.0  2020  09        06703  0037  Urbano    0.0        NaN  URBANO
# 7      2.0  2020  09        03981  0057  Urbano    0.0        NaN  URBANO
# ...    ...   ...  ..          ...   ...     ...    ...        ...     ...
# 42148  2.0  2020  05        51489  0073  Urbano    0.0        NaN  URBANO
# 42149  2.0  2020  05        51489  0079  Urbano    0.0        NaN  URBANO
# 42150  3.0  2020  08        51548  0026  Urbano    0.0        NaN  URBANO
# 42151  3.0  2020  08        51548  0046  Urbano    0.0        NaN  URBANO
# 42152  3.0  2020  08        51548  0066  Urbano    0.0        NaN  URBANO
#
#       CCDD  ... P189_5 P189_6 P189_7 P189_8 P189_8_O REGIONNATU  \
# ...

# %%
df_urb_compl = enapres2020_1.loc[ (enapres2020_1.AREA == 'URBANO') &  (enapres2020_1.RESFIN == 'Completa') , : ]
df_urb_compl
# Out:
#        PER  ANIO MES CONGLOMERADO NSELV   TSELV VIVREM  NUMVIVREM    AREA  \
# 1      2.0  2020  09        03981  0120  Urbano    0.0        NaN  URBANO
# 2      2.0  2020  09        03981  0189  Urbano    0.0        NaN  URBANO
# 3      2.0  2020  09        03981  0189  Urbano    0.0        NaN  URBANO
# 6      2.0  2020  09        06703  0037  Urbano    0.0        NaN  URBANO
# 7      2.0  2020  09        03981  0057  Urbano    0.0        NaN  URBANO
# ...    ...   ...  ..          ...   ...     ...    ...        ...     ...
# 42148  2.0  2020  05        51489  0073  Urbano    0.0        NaN  URBANO
# 42149  2.0  2020  05        51489  0079  Urbano    0.0        NaN  URBANO
# 42150  3.0  2020  08        51548  0026  Urbano    0.0        NaN  URBANO
# 42151  3.0  2020  08        51548  0046  Urbano    0.0        NaN  URBANO
# 42152  3.0  2020  08        51548  0066  Urbano    0.0        NaN  URBANO
#
#       CCDD  ... P189_5 P189_6 P189_7 P189_8 P189_8_O REGIONNATU  \
# ...

# %%
# We will work on this variable
df_urban.attrs[ 'var_labels' ]['P172D']
# Out:
# '¿USTED O ALGÚN MIEMBRO DE SU HOGAR SEPARA LOS RESIDUOS GENERADOS EN SU HOGAR?'

# %%
df_urban.columns
# Out:
# Index(['PER', 'ANIO', 'MES', 'CONGLOMERADO', 'NSELV', 'TSELV', 'VIVREM',
#        'NUMVIVREM', 'AREA', 'CCDD',
#        ...
#        'P189_5', 'P189_6', 'P189_7', 'P189_8', 'P189_8_O', 'REGIONNATU',
#        'ESTRATO', 'MOD_ENC', 'FACTOR', 'FACTOR_CALIBRADO'],
#       dtype='object', length=491)

# %%
P172

# %%
# Select columns with regex
# All the columns that start with P172
df_urban.filter( regex = "P172*").columns
# Out:
# Index(['P172B_1', 'P172C_1', 'P172B_2', 'P172C_2', 'P172D', 'P172E_1',
#        'P172F_1_1', 'P172F_1_2', 'P172F_1_3', 'P172F_1_4', 'P172F_1_5',
#        'P172F_1_6', 'P172F_1_6_O', 'P172E_2', 'P172F_2_1', 'P172F_2_2',
#        'P172F_2_3', 'P172F_2_4', 'P172F_2_5', 'P172F_2_6', 'P172F_2_6_O',
#        'P172E_3', 'P172F_3_1', 'P172F_3_2', 'P172F_3_3', 'P172F_3_4',
#        'P172F_3_5', 'P172F_3_6', 'P172F_3_6_O', 'P172E_4', 'P172F_4_1',
#        'P172F_4_2', 'P172F_4_3', 'P172F_4_4', 'P172F_4_5', 'P172F_4_6',
#        'P172F_4_6_O', 'P172E_5', 'P172F_5_1', 'P172F_5_2', 'P172F_5_3',
#        'P172F_5_4', 'P172F_5_5', 'P172F_5_6', 'P172F_5_6_O', 'P172E_6',
#        'P172F_6_1', 'P172F_6_2', 'P172F_6_3', 'P172F_6_4', 'P172F_6_5',
#        'P172F_6_6', 'P172F_6_6_O', 'P172E_7', 'P172E_7_O', 'P172F_7_1',
#        'P172F_7_2', 'P172F_7_3', 'P172F_7_4', 'P172F_7_5', 'P172F_7_6',
#        'P172F_7_6_O', 'P172G', 'P172H_1', 'P172H_2', 'P172H_3', 'P172H_4',
# ...

# %%
# all columns that have an X
df_urban.filter( like = "P172")
# Out:
#       P172B_1          P172C_1  P172B_2               P172C_2 P172D P172E_1  \
# 1          No              NaN      1.0       Insatisfecho/a?    Si      No
# 2          No              NaN      1.0       Insatisfecho/a?    Si      No
# 3          No              NaN      1.0       Insatisfecho/a?    Si      Si
# 6          Si  Insatisfecho/a?      1.0       Insatisfecho/a?    Si      No
# 7          No              NaN      1.0       Insatisfecho/a?    Si      Si
# ...       ...              ...      ...                   ...   ...     ...
# 42148      No              NaN      1.0       Insatisfecho/a?    Si      Si
# 42149      No              NaN      1.0   Muy insatisfecho/a?    Si      Si
# 42150      No              NaN      1.0       Insatisfecho/a?    No     NaN
# 42151      No              NaN      1.0         Satisfecho/a?    Si      No
# 42152      No              NaN      1.0       Insatisfecho/a?    No     NaN
#
# ...

# %% [markdown]
# ### 3.3.6. <a id='3.3.6'>Dealing with nulls</a>

# %% [markdown]
# We drop columns that at least 30% values are null to simplify our Exploratory Data Analysis (EDA).

# %%
df_urban
# Out:
#        PER  ANIO MES CONGLOMERADO NSELV   TSELV VIVREM  NUMVIVREM    AREA  \
# 1      2.0  2020  09        03981  0120  Urbano    0.0        NaN  URBANO
# 2      2.0  2020  09        03981  0189  Urbano    0.0        NaN  URBANO
# 3      2.0  2020  09        03981  0189  Urbano    0.0        NaN  URBANO
# 6      2.0  2020  09        06703  0037  Urbano    0.0        NaN  URBANO
# 7      2.0  2020  09        03981  0057  Urbano    0.0        NaN  URBANO
# ...    ...   ...  ..          ...   ...     ...    ...        ...     ...
# 42148  2.0  2020  05        51489  0073  Urbano    0.0        NaN  URBANO
# 42149  2.0  2020  05        51489  0079  Urbano    0.0        NaN  URBANO
# 42150  3.0  2020  08        51548  0026  Urbano    0.0        NaN  URBANO
# 42151  3.0  2020  08        51548  0046  Urbano    0.0        NaN  URBANO
# 42152  3.0  2020  08        51548  0066  Urbano    0.0        NaN  URBANO
#
#       CCDD  ... P189_5 P189_6 P189_7 P189_8 P189_8_O REGIONNATU  \
# ...

# %%
df_urban.isnull()
# Out:
#          PER   ANIO    MES  CONGLOMERADO  NSELV  TSELV  VIVREM  NUMVIVREM  \
# 1      False  False  False         False  False  False   False       True
# 2      False  False  False         False  False  False   False       True
# 3      False  False  False         False  False  False   False       True
# 6      False  False  False         False  False  False   False       True
# 7      False  False  False         False  False  False   False       True
# ...      ...    ...    ...           ...    ...    ...     ...        ...
# 42148  False  False  False         False  False  False   False       True
# 42149  False  False  False         False  False  False   False       True
# 42150  False  False  False         False  False  False   False       True
# 42151  False  False  False         False  False  False   False       True
# 42152  False  False  False         False  False  False   False       True
#
#         AREA   CCDD  ...  P189_5  P189_6  P189_7  P189_8  P189_8_O  \
# ...

# %%
df_urban.isnull().sum()
# Out:
# PER                     0
# ANIO                    0
# MES                     0
# CONGLOMERADO            0
# NSELV                   0
#                     ...
# REGIONNATU              0
# ESTRATO                 0
# MOD_ENC                 0
# FACTOR                  0
# FACTOR_CALIBRADO    12230
# Length: 491, dtype: int64

# %%
null_sum = df_urban.isnull().sum()
null_sum
# Out:
# PER                     0
# ANIO                    0
# MES                     0
# CONGLOMERADO            0
# NSELV                   0
#                     ...
# REGIONNATU              0
# ESTRATO                 0
# MOD_ENC                 0
# FACTOR                  0
# FACTOR_CALIBRADO    12230
# Length: 491, dtype: int64

# %%
len( df_urban ) * 0.3
# Out:
# 7304.099999999999

# %%
df_urban.columns[ null_sum < len( df_urban ) * 0.3 ]
# Out:
# Index(['PER', 'ANIO', 'MES', 'CONGLOMERADO', 'NSELV', 'TSELV', 'VIVREM',
#        'AREA', 'CCDD', 'NOMBREDD',
#        ...
#        'P184A_15', 'P184A_16', 'P184A_17', 'P184A_18', 'P187_9_O', 'P189_8_O',
#        'REGIONNATU', 'ESTRATO', 'MOD_ENC', 'FACTOR'],
#       dtype='object', length=120)

# %%
df_urban
# Out:
#        PER  ANIO MES CONGLOMERADO NSELV   TSELV VIVREM  NUMVIVREM    AREA  \
# 1      2.0  2020  09        03981  0120  Urbano    0.0        NaN  URBANO
# 2      2.0  2020  09        03981  0189  Urbano    0.0        NaN  URBANO
# 3      2.0  2020  09        03981  0189  Urbano    0.0        NaN  URBANO
# 6      2.0  2020  09        06703  0037  Urbano    0.0        NaN  URBANO
# 7      2.0  2020  09        03981  0057  Urbano    0.0        NaN  URBANO
# ...    ...   ...  ..          ...   ...     ...    ...        ...     ...
# 42148  2.0  2020  05        51489  0073  Urbano    0.0        NaN  URBANO
# 42149  2.0  2020  05        51489  0079  Urbano    0.0        NaN  URBANO
# 42150  3.0  2020  08        51548  0026  Urbano    0.0        NaN  URBANO
# 42151  3.0  2020  08        51548  0046  Urbano    0.0        NaN  URBANO
# 42152  3.0  2020  08        51548  0066  Urbano    0.0        NaN  URBANO
#
#       CCDD  ... P189_5 P189_6 P189_7 P189_8 P189_8_O REGIONNATU  \
# ...

# %%
df_urban.drop(columns = df_urban.columns[null_sum > len( df_urban ) * 0.3 ], inplace = True )
df_urban
# Out:
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_20560/2430473974.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_urban.drop(columns = df_urban.columns[null_sum > len( df_urban ) * 0.3 ], inplace = True )
#        PER  ANIO MES CONGLOMERADO NSELV   TSELV VIVREM    AREA CCDD  \
# 1      2.0  2020  09        03981  0120  Urbano    0.0  URBANO   14
# 2      2.0  2020  09        03981  0189  Urbano    0.0  URBANO   14
# 3      2.0  2020  09        03981  0189  Urbano    0.0  URBANO   14
# 6      2.0  2020  09        06703  0037  Urbano    0.0  URBANO   01
# 7      2.0  2020  09        03981  0057  Urbano    0.0  URBANO   14
# ...    ...   ...  ..          ...   ...     ...    ...     ...  ...
# 42148  2.0  2020  05        51489  0073  Urbano    0.0  URBANO   18
# ...

# %%
df_urban.attrs['var_labels']
# Out:
# {'PER': 'PERIODO',
#  'ANIO': 'AÑO',
#  'MES': 'MES DE LA ENCUESTA',
#  'CONGLOMERADO': 'N° de conglomerado',
#  'NSELV': 'Nº de selección de la vivienda',
#  'TSELV': 'Tipo de selección de la vivienda',
#  'VIVREM': '¿Es una vivienda de reemplazo?',
#  'NUMVIVREM': 'Anote el número de selección de la vivienda reemplazada',
#  'AREA': 'AREA',
#  'CCDD': 'Código de Departamento',
#  'NOMBREDD': 'Nombre de Departamento',
#  'CCPP': 'Código de Provincia',
#  'NOMBREPP': 'Nombre de la Provincia',
#  'CCDI': 'Código del Distrito',
#  'NOMBREDI': 'Nombre del Distrito',
#  'VIVIENDA': 'N° de Vivienda',
#  'TOT_HOGAR': '¿Cuántos hogares ocupa esta vivienda?',
#  'HOGAR': 'Hogar N°',
#  'RESFIN': 'Resultado final del hogar',
#  'P100_C': 'INFORMANTE N°',
#  'P101': 'TIPO DE VIVIENDA',
#  'P101_O': 'TIPO DE VIVIENDA: ESPECIFIQUE',
#  'P102A': 'EN LA VIVIENDA, ¿EL MATERIAL DE CONSTRUCCIÓN PREDOMINANTE EN LAS PAREDES EXTERIORES ES DE:',
# ...

# %%
df_urban
# Out:
#        PER  ANIO MES CONGLOMERADO NSELV   TSELV VIVREM    AREA CCDD  \
# 1      2.0  2020  09        03981  0120  Urbano    0.0  URBANO   14
# 2      2.0  2020  09        03981  0189  Urbano    0.0  URBANO   14
# 3      2.0  2020  09        03981  0189  Urbano    0.0  URBANO   14
# 6      2.0  2020  09        06703  0037  Urbano    0.0  URBANO   01
# 7      2.0  2020  09        03981  0057  Urbano    0.0  URBANO   14
# ...    ...   ...  ..          ...   ...     ...    ...     ...  ...
# 42148  2.0  2020  05        51489  0073  Urbano    0.0  URBANO   18
# 42149  2.0  2020  05        51489  0079  Urbano    0.0  URBANO   18
# 42150  3.0  2020  08        51548  0026  Urbano    0.0  URBANO   23
# 42151  3.0  2020  08        51548  0046  Urbano    0.0  URBANO   23
# 42152  3.0  2020  08        51548  0066  Urbano    0.0  URBANO   23
#
#          NOMBREDD  ... P184A_15       P184A_16 P184A_17 P184A_18 P187_9_O  \
# 1      LAMBAYEQUE  ...     Pase           Pase     Pase     Pase
# ...

# %%
# cheack ID in pandas
( df_urban['PER'].astype(str)+ "_" + 
 df_urban['MES'].astype(str)+ "_" + 
 df_urban['CCDD'].astype(str) + "_" + 
 df_urban['CCPP'].astype(str) + "_" + 
 df_urban['CCDI'].astype(str) + "_" + 
 df_urban['CONGLOMERADO'].astype(str) + "_" + 
 df_urban['NSELV'].astype(str) + "_" +
 df_urban['VIVIENDA'].astype(str) + "_" + 
 df_urban['HOGAR'].astype(int).astype(str) 
).is_unique
# Out:
# True

# %% [markdown]
# ### 3.3.7. <a id='3.3.7'>[Duplicates](https://thispointer.com/pandas-find-duplicate-rows-in-a-dataframe-based-on-all-or-selected-columns-using-dataframe-duplicated-in-python/)</a>
#
# See duplicatedes in rows.

# %%
df_urban[ df_urban.loc[ : , ['CCDD' ,'CCPP' , 'CCDI' ,'CONGLOMERADO' , 
                             'NSELV', 'VIVIENDA', 'HOGAR'] ].duplicated( keep=False) ]
# Out:
#        PER  ANIO MES CONGLOMERADO NSELV   TSELV VIVREM    AREA CCDD  \
# 4848   1.0  2020  07        39066  0140  Urbano    0.0  URBANO   17
# 5693   3.0  2020  12        36856  0003  Urbano    0.0  URBANO   03
# 26150  2.0  2020  05        15120  0110  Urbano    0.0  URBANO   25
# 26157  2.0  2020  06        15120  0110  Urbano    0.0  URBANO   25
# 36993  1.0  2020  06        36856  0003  Urbano    0.0  URBANO   03
# 37886  1.0  2020  06        38913  0008  Urbano    0.0  URBANO   17
# 37889  1.0  2020  08        38913  0008  Urbano    0.0  URBANO   17
# 38215  2.0  2020  06        39066  0140  Urbano    0.0  URBANO   17
# 39625  3.0  2020  07        43264  0008  Urbano    0.0  URBANO   04
# 39631  1.0  2020  10        43264  0008  Urbano    0.0  URBANO   04
#
#             NOMBREDD  ...                P184A_15       P184A_16 P184A_17  \
# 4848   MADRE DE DIOS  ...                    Pase  ¿Motocicleta?     Pase
# ...

# %% [markdown]
# We will drop the last duplication.

# %%
df_urban.shape
# Out:
# (24347, 120)

# %%
df_urban_no_dpl = df_urban[ ~ df_urban.loc[:, ['CCDD' ,'CCPP' , 'CCDI' ,'CONGLOMERADO' , 'NSELV', 
                                               'VIVIENDA', 'HOGAR'] ].duplicated() ].copy()
df_urban_no_dpl
# Out:
#        PER  ANIO MES CONGLOMERADO NSELV   TSELV VIVREM    AREA CCDD  \
# 1      2.0  2020  09        03981  0120  Urbano    0.0  URBANO   14
# 2      2.0  2020  09        03981  0189  Urbano    0.0  URBANO   14
# 3      2.0  2020  09        03981  0189  Urbano    0.0  URBANO   14
# 6      2.0  2020  09        06703  0037  Urbano    0.0  URBANO   01
# 7      2.0  2020  09        03981  0057  Urbano    0.0  URBANO   14
# ...    ...   ...  ..          ...   ...     ...    ...     ...  ...
# 42148  2.0  2020  05        51489  0073  Urbano    0.0  URBANO   18
# 42149  2.0  2020  05        51489  0079  Urbano    0.0  URBANO   18
# 42150  3.0  2020  08        51548  0026  Urbano    0.0  URBANO   23
# 42151  3.0  2020  08        51548  0046  Urbano    0.0  URBANO   23
# 42152  3.0  2020  08        51548  0066  Urbano    0.0  URBANO   23
#
#          NOMBREDD  ... P184A_15       P184A_16 P184A_17 P184A_18 P187_9_O  \
# 1      LAMBAYEQUE  ...     Pase           Pase     Pase     Pase
# ...

# %%
df_urban_no_dpl.value_counts()
# Out:
# PER  ANIO  MES  CONGLOMERADO  NSELV  TSELV   VIVREM  AREA    CCDD  NOMBREDD   CCPP  NOMBREPP               CCDI  NOMBREDI   VIVIENDA  TOT_HOGAR  HOGAR  RESFIN    P100_C  P101_O  P102A_O  P103_O  P104B_O  P106_O  P107A_O                    P107B_O                         P108_1_O  P108B_O  P109  P110A  P110AA  P111A  P112_1  P113B_1_3_O  P118_1_O  P119_1_O  P121_1_O  P116_1_5_O  P121D_1_5_O  P112_2  P113B_2_3_O  P118_2_O  P119_2_O  P121_2_O  P116_2_5_O  P121D_2_5_O  P122A_6_O       P122D_O  P127_1        P127_2  P127_3  P127_4  P127_5  P127_6  P127_6_O  P128A_1        P128A_2           P128A_3                             P128A_4  P128A_5  P128A_6  P128A_7  P128A_8     P128A_O  P129G                                P129G_O  P129B  P100_C_2  P129F_O  P130  P130A  P131_7_O  P131B_O  P131C_B  P131D_O  P137_O  P139_O  P141_7_O  P142A                                           P142A_O                     P159_O  P172B_1  P172B_2  P172C_2               P172D  P172F_1_6_O  P172F_2_6_O  P172F_3_
# ...

# %%
df_urban_no_dpl.ESTRATO
# Out:
# 1                 Estrato D
# 2                 Estrato D
# 3                 Estrato D
# 6        Estrato E más bajo
# 7                 Estrato D
#                 ...
# 42148             Estrato D
# 42149             Estrato D
# 42150    Estrato E más bajo
# 42151    Estrato E más bajo
# 42152    Estrato E más bajo
# Name: ESTRATO, Length: 24342, dtype: category
# Categories (5, object): ['Estrato A más alto', 'Estrato B', 'Estrato C', 'Estrato D', 'Estrato E más bajo']

# %% [markdown]
# ### 3.3.8. <a id='3.3.8'>Groupby</a>

# %%
df_urban_no_dpl.attrs['var_labels']
# Out:
# {'PER': 'PERIODO',
#  'ANIO': 'AÑO',
#  'MES': 'MES DE LA ENCUESTA',
#  'CONGLOMERADO': 'N° de conglomerado',
#  'NSELV': 'Nº de selección de la vivienda',
#  'TSELV': 'Tipo de selección de la vivienda',
#  'VIVREM': '¿Es una vivienda de reemplazo?',
#  'NUMVIVREM': 'Anote el número de selección de la vivienda reemplazada',
#  'AREA': 'AREA',
#  'CCDD': 'Código de Departamento',
#  'NOMBREDD': 'Nombre de Departamento',
#  'CCPP': 'Código de Provincia',
#  'NOMBREPP': 'Nombre de la Provincia',
#  'CCDI': 'Código del Distrito',
#  'NOMBREDI': 'Nombre del Distrito',
#  'VIVIENDA': 'N° de Vivienda',
#  'TOT_HOGAR': '¿Cuántos hogares ocupa esta vivienda?',
#  'HOGAR': 'Hogar N°',
#  'RESFIN': 'Resultado final del hogar',
#  'P100_C': 'INFORMANTE N°',
#  'P101': 'TIPO DE VIVIENDA',
#  'P101_O': 'TIPO DE VIVIENDA: ESPECIFIQUE',
#  'P102A': 'EN LA VIVIENDA, ¿EL MATERIAL DE CONSTRUCCIÓN PREDOMINANTE EN LAS PAREDES EXTERIORES ES DE:',
# ...

# %%
# from yes to 1 and 0 to no
df_urban_no_dpl.P172D.replace(('Si', 'No'), (1, 0), inplace=True)
df_urban_no_dpl.P172D
# Out:
# 1        1
# 2        1
# 3        1
# 6        1
# 7        1
#         ..
# 42148    1
# 42149    1
# 42150    0
# 42151    1
# 42152    0
# Name: P172D, Length: 24342, dtype: category
# Categories (2, int64): [0, 1]

# %%
df_urban_no_dpl.P172D.value_counts()
# Out:
# 0    13254
# 1    11088
# Name: P172D, dtype: int64

# %%
df_urban_no_dpl.groupby( [ 'CCDD' ,'CCPP' , 'CCDI', 'P172D' ] )[['P172D']].sum()
# Out:
# <ipython-input-96-6b501f7bb432>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_urban_no_dpl.groupby( [ 'CCDD' ,'CCPP' , 'CCDI', 'P172D' ] )[['P172D']].sum()
# Empty DataFrame
# Columns: []
# ...

# %%
df_urban_no_dpl.groupby( [ 'CCDD' ,'CCPP' , 'CCDI' ] )[['P172D']].mean()
# Out:
# <ipython-input-97-c6dc87d3d338>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_urban_no_dpl.groupby( [ 'CCDD' ,'CCPP' , 'CCDI' ] )[['P172D']].mean()
# Empty DataFrame
# Columns: []
# ...

# %%
df_urban_no_dpl.groupby( [ 'CCDD' ,'CCPP' , 'CCDI' ], as_index = False )[['P172D']].mean()
# Out:
# <ipython-input-98-419bfc818594>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_urban_no_dpl.groupby( [ 'CCDD' ,'CCPP' , 'CCDI' ], as_index = False )[['P172D']].mean()
#     CCDD CCPP CCDI
# 0     01   01   01
# 1     01   01   09
# 2     01   02   01
# 3     01   02   02
# 4     01   02   03
# ..   ...  ...  ...
# 545   25   02   02
# 546   25   03   01
# 547   25   03   02
# 548   25   03   04
# 549   25   03   05
#
# [550 rows x 3 columns]

# %% [markdown]
# #### [Agg](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.agg.html)
# Aggregate using one or more operations over the specified axis.

# %%
df_urban_no_dpl['P172D'] = df_urban_no_dpl['P172D'].astype( float )

# %%
df_urban_no_dpl.groupby( [ 'CCDD' ,'CCPP' , 'CCDI' ], as_index = False ).agg( { "P172D": "mean" } )
# Out:
#     CCDD CCPP CCDI     P172D
# 0     01   01   01  0.674074
# 1     01   01   09  0.750000
# 2     01   02   01  0.648148
# 3     01   02   02  0.125000
# 4     01   02   03  0.714286
# ..   ...  ...  ...       ...
# 545   25   02   02  0.000000
# 546   25   03   01  0.061728
# 547   25   03   02  0.216216
# 548   25   03   04  0.000000
# 549   25   03   05  0.142857
#
# [550 rows x 4 columns]

# %%
import numpy as np

# %%
df3_rec = df_urban_no_dpl.groupby( [ 'CCDD' ,'CCPP' , 'CCDI' ] , 
                                as_index = False 
                               ).agg( 
                                    recycle_median = ( 'P172D', np.median ), 
                                    recycle_mean = ( 'P172D', np.mean ) 
                                )
df3_rec
# Out:
#     CCDD CCPP CCDI  recycle_median  recycle_mean
# 0     01   01   01             1.0      0.674074
# 1     01   01   09             1.0      0.750000
# 2     01   02   01             1.0      0.648148
# 3     01   02   02             0.0      0.125000
# 4     01   02   03             1.0      0.714286
# ..   ...  ...  ...             ...           ...
# 545   25   02   02             0.0      0.000000
# 546   25   03   01             0.0      0.061728
# 547   25   03   02             0.0      0.216216
# 548   25   03   04             0.0      0.000000
# 549   25   03   05             0.0      0.142857
#
# [550 rows x 5 columns]

# %% [markdown]
# ### 3.3.9. <a id='3.3.9'>Reshape</a>

# %% [markdown]
# #####  From Wide to Long

# %%
df3_rec.head()
# Out:
#   CCDD CCPP CCDI  recycle_median  recycle_mean
# 0   01   01   01             1.0      0.674074
# 1   01   01   09             1.0      0.750000
# 2   01   02   01             1.0      0.648148
# 3   01   02   02             0.0      0.125000
# 4   01   02   03             1.0      0.714286

# %%
df3_rec_stack = df3_rec.set_index(  [ 'CCDD' ,'CCPP' , 'CCDI' ]  ).stack().reset_index().rename( {"level_3" : "STATS", 
                                                                                0 : "VALUES" }, axis = 1 )
df3_rec_stack.head()
# Out:
#   CCDD CCPP CCDI           STATS    VALUES
# 0   01   01   01  recycle_median  1.000000
# 1   01   01   01    recycle_mean  0.674074
# 2   01   01   09  recycle_median  1.000000
# 3   01   01   09    recycle_mean  0.750000
# 4   01   02   01  recycle_median  1.000000

# %%
df3_rec_melt = df3_rec.melt( 
                    id_vars = [ 'CCDD' ,'CCPP' , 'CCDI' ] ,
                    var_name = 'STATS', 
                    value_name = 'VALUES'
                 )
df3_rec_melt
# Out:
#      CCDD CCPP CCDI           STATS    VALUES
# 0      01   01   01  recycle_median  1.000000
# 1      01   01   09  recycle_median  1.000000
# 2      01   02   01  recycle_median  1.000000
# 3      01   02   02  recycle_median  0.000000
# 4      01   02   03  recycle_median  1.000000
# ...   ...  ...  ...             ...       ...
# 1095   25   02   02    recycle_mean  0.000000
# 1096   25   03   01    recycle_mean  0.061728
# 1097   25   03   02    recycle_mean  0.216216
# 1098   25   03   04    recycle_mean  0.000000
# 1099   25   03   05    recycle_mean  0.142857
#
# [1100 rows x 5 columns]

# %% [markdown]
# ##### From Long to Wide

# %%
df3_rec_stack.set_index(  [ 'CCDD' ,'CCPP' , 'CCDI' , "STATS" ]  ).unstack().head()
# Out:
#                      VALUES
# STATS          recycle_mean recycle_median
# CCDD CCPP CCDI
# 01   01   01       0.674074            1.0
#           09       0.750000            1.0
#      02   01       0.648148            1.0
#           02       0.125000            0.0
#           03       0.714286            1.0

# %%
df4 = df3_rec_stack.set_index(  [ 'CCDD' ,'CCPP' , 'CCDI' , "STATS" ]   ).unstack().rename_axis( [None, None], axis = 1 )


df4.columns = df3_rec_stack.STATS.unique()

df4.reset_index().head()
# Out:
#   CCDD CCPP CCDI  recycle_median  recycle_mean
# 0   01   01   01        0.674074           1.0
# 1   01   01   09        0.750000           1.0
# 2   01   02   01        0.648148           1.0
# 3   01   02   02        0.125000           0.0
# 4   01   02   03        0.714286           1.0

# %%
df_l_w = df3_rec_stack.pivot( index = [ 'CCDD' ,'CCPP' , 'CCDI' ], 
                         columns = 'STATS' ,
                         values = 'VALUES' 
                        ).rename_axis( [None], axis = 1 ).reset_index()
df_l_w.head()
# Out:
#   CCDD CCPP CCDI  recycle_mean  recycle_median
# 0   01   01   01      0.674074             1.0
# 1   01   01   09      0.750000             1.0
# 2   01   02   01      0.648148             1.0
# 3   01   02   02      0.125000             0.0
# 4   01   02   03      0.714286             1.0

# %% [markdown]
# ### 3.3.10. <a id='3.3.10'>[Merge](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html)</a>

# %%
df_urban_merge = df_urban_no_dpl.merge( df_l_w , on = [ 'CCDD' ,'CCPP' , 'CCDI' ] , how = "left" , validate = "m:1" ).head()

# %%
df_urban_merge.head()
# Out:
#    PER  ANIO MES CONGLOMERADO NSELV   TSELV VIVREM    AREA CCDD    NOMBREDD  \
# 0  2.0  2020  09        03981  0120  Urbano    0.0  URBANO   14  LAMBAYEQUE
# 1  2.0  2020  09        03981  0189  Urbano    0.0  URBANO   14  LAMBAYEQUE
# 2  2.0  2020  09        03981  0189  Urbano    0.0  URBANO   14  LAMBAYEQUE
# 3  2.0  2020  09        06703  0037  Urbano    0.0  URBANO   01    AMAZONAS
# 4  2.0  2020  09        03981  0057  Urbano    0.0  URBANO   14  LAMBAYEQUE
#
#    ... P184A_17 P184A_18 P187_9_O P189_8_O REGIONNATU             ESTRATO  \
# 0  ...     Pase     Pase                        COSTA           Estrato D
# 1  ...     Pase     Pase                        COSTA           Estrato D
# 2  ...     Pase     Pase                        COSTA           Estrato D
# 3  ...     Pase     Pase                        SELVA  Estrato E más bajo
# 4  ...     Pase     Pase                        COSTA           Estrato D
#
#          MOD_ENC     FACTOR  recycle_mean recycle_median
# ...

# %%
# See all your DataFrames
# %whos DataFrame
# Out:
# Variable               Type         Data/Info
# ---------------------------------------------
# cars                   DataFrame        brands  model  passen<...>   kia  truck           8
# cars_subset            DataFrame        brands  model  passen<...>   kia  sedan           5
# data2                  DataFrame       a  b  c\n0  1  2  3\n1  4  5  6\n2  7  8  9
# dep1                   DataFrame          dep  year  pop\n0  <...>2.9\n5    Puno  2003  3.2
# dep1_sort              DataFrame          dep  year  pop\n5  <...>1.7\n0    Lima  2000  1.5
# df3_rec                DataFrame        CCDD CCPP CCDI  recyc<...>n\n[550 rows x 5 columns]
# df3_rec_melt           DataFrame         CCDD CCPP CCDI      <...>\n[1100 rows x 5 columns]
# df3_rec_stack          DataFrame         CCDD CCPP CCDI      <...>\n[1100 rows x 5 columns]
# df4                    DataFrame                    recycle_m<...>n\n[550 rows x 2 columns]
# ...
